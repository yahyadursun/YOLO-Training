# %% [markdown]
# "--------------------------------------------------Yolov5--------------------------------------------"

# %%
# Step 1: Setup YOLOv5 Environment
# Clone the official YOLOv5 repository from Ultralytics
# !git clone https://github.com/ultralytics/yolov5  # clone
# Change working directory to YOLOv5
# %cd yolov5
# Install all required dependencies silently (-q flag) and comet_ml for experiment tracking
# %pip install -qr requirements.txt comet_ml  # install

# Initialize YOLO and verify GPU/CUDA availability
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-286-g41603da1 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %%
# Unzip the training data from train_data.zip into the content directory
# !unzip ../content/train_data.zip -d ../content/

# %%
# Train YOLOv5s on COCO128 for 120 epochs
# !python train.py --img 640 --batch 8 --epochs 200 --data custom_data.yaml --weights yolov5s.pt --cache

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/last.pt --img 640 --conf 0.25 --source ../clover.mp4
# Run detection on video file using trained weights from exp3 with 640px input size and 0.25 confidence threshold

# %%
# Copy trained model results to Google Drive for persistence

# !scp -r ../yolov5/runs '/content/drive/MyDrive/ComputerVisionEngineer/ObjectDetectionYolov5'

# %% [markdown]
# "--------------------------------------------------Yolov8--------------------------------------------"

# %%
# Install ultralytics package and verify environment setup for YOLOv8 training
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/78.2 GB disk)

# %%
# Download YOLOv8 model weights and prepare for training on custom dataset
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:03<00:00, 252MB/s]

# %%
# Train YOLOv8n on COCO8 for 100 epochs
# !yolo train model=yolov8n.pt data=data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Copy trained YOLOv8 model results to Google Drive for persistence

# !scp -r /content/runs/detect/train13 '/content/drive/MyDrive/ComputerVisionEngineer/ObjectDetectionYolov8/new1'
# Out:
# Sistem belirtilen yolu bulamıyor.
